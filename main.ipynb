# %%
import numpy as np

# %%
import pandas as pd

# %%
data = pd.read_csv("usedCars.csv")

# %%
data.isnull().sum()
# Out:
# Id                     0
# Company                0
# Model                  0
# Variant                0
# FuelType               1
# Colour                 0
# Kilometer              0
# BodyStyle              0
# TransmissionType     714
# ManufactureDate        0
# ModelYear              0
# CngKit              1042
# Price                  0
# Owner                  0
# DealerState            0
# DealerName             0
# City                   0
# Warranty               0
# QualityScore           0
# dtype: int64

# %%
transmission_mode=data['TransmissionType'].mode()

# %%
transmission_mode=transmission_mode[0]

# %%
data['TransmissionType']=data['TransmissionType'].fillna(transmission_mode)

# %%
data.isnull().sum()
# Out:
# Id                     0
# Company                0
# Model                  0
# Variant                0
# FuelType               1
# Colour                 0
# Kilometer              0
# BodyStyle              0
# TransmissionType       0
# ManufactureDate        0
# ModelYear              0
# CngKit              1042
# Price                  0
# Owner                  0
# DealerState            0
# DealerName             0
# City                   0
# Warranty               0
# QualityScore           0
# dtype: int64

# %%
fuel_mode=np.array(data['FuelType'].mode())

# %%
fuel_mode=fuel_mode[0]

# %%
type(fuel_mode)
# Out:
# str

# %%
data['FuelType'] = data['FuelType'].fillna(fuel_mode)

# %%
data
# Out:
#           Id        Company                 Model           Variant FuelType  \
# 0     555675  MARUTI SUZUKI    CELERIO(2017-2019)     1.0 ZXI AMT O   PETROL
# 1     556383  MARUTI SUZUKI                  ALTO               LXI   PETROL
# 2     556422        HYUNDAI             GRAND I10    1.2 KAPPA ASTA   PETROL
# 3     556771           TATA                 NEXON           XT PLUS   PETROL
# 4     559619           FORD                  FIGO  EXI DURATORQ 1.4   DIESEL
# ...      ...            ...                   ...               ...      ...
# 1059  588906        HYUNDAI  ELITE I20(2020-2020)  ASTA O 1.2 BS VI   PETROL
# 1060  588945        HYUNDAI      XCENT(2017-2020)                 S   PETROL
# 1061  588946       MAHINDRA    SCORPIO(2009-2014)    VLX 2WD BS-III   DIESEL
# 1062  588949  MARUTI SUZUKI         VITARA BREZZA               VDI   DIESEL
# 1063  588950          HONDA                  CITY      SV MT DIESEL   DIESEL
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1064 entries, 0 to 1063
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                1064 non-null   int64
#  1   Company           1064 non-null   str
#  2   Model             1064 non-null   str
#  3   Variant           1064 non-null   str
#  4   FuelType          1064 non-null   str
#  5   Colour            1064 non-null   str
#  6   Kilometer         1064 non-null   int64
#  7   BodyStyle         1064 non-null   str
#  8   TransmissionType  1064 non-null   str
#  9   ManufactureDate   1064 non-null   str
#  10  ModelYear         1064 non-null   int64
#  11  CngKit            22 non-null     str
#  12  Price             1064 non-null   str
#  13  Owner             1064 non-null   str
#  14  DealerState       1064 non-null   str
#  15  DealerName        1064 non-null   str
#  16  City              1064 non-null   str
# ...

# %%
data.describe(include='all')
# Out:
#                    Id        Company  Model Variant FuelType Colour  \
# count     1064.000000           1064   1064    1064     1064   1064
# unique            NaN             23    218     575        5     76
# top               NaN  MARUTI SUZUKI  SWIFT     VXI   PETROL  White
# freq              NaN            252     38      37      671    289
# mean    568156.542293            NaN    NaN     NaN      NaN    NaN
# std      16438.139974            NaN    NaN     NaN      NaN    NaN
# min     525978.000000            NaN    NaN     NaN      NaN    NaN
# 25%     555321.500000            NaN    NaN     NaN      NaN    NaN
# 50%     572753.000000            NaN    NaN     NaN      NaN    NaN
# 75%     583072.750000            NaN    NaN     NaN      NaN    NaN
# max     589122.000000            NaN    NaN     NaN      NaN    NaN
#
#             Kilometer  BodyStyle TransmissionType ManufactureDate  \
# count     1064.000000       1064             1064            1064
# ...

# %%
data.columns = data.columns.str.lower()

# %%
data.head()
# Out:
#        id        company               model           variant fueltype  \
# 0  555675  MARUTI SUZUKI  CELERIO(2017-2019)     1.0 ZXI AMT O   PETROL
# 1  556383  MARUTI SUZUKI                ALTO               LXI   PETROL
# 2  556422        HYUNDAI           GRAND I10    1.2 KAPPA ASTA   PETROL
# 3  556771           TATA               NEXON           XT PLUS   PETROL
# 4  559619           FORD                FIGO  EXI DURATORQ 1.4   DIESEL
#
#    colour  kilometer  bodystyle transmissiontype manufacturedate  modelyear  \
# 0  Silver      33197  HATCHBACK           Manual      2018-02-01       2018
# 1     Red      10322  HATCHBACK           Manual      2021-03-01       2021
# 2    Grey      37889  HATCHBACK           Manual      2015-03-01       2015
# 3  A Blue      13106  HATCHBACK           Manual      2020-08-01       2020
# 4  Silver     104614  HATCHBACK           Manual      2010-11-01       2010
#
# ...

# %%
data['cngkit']=data['cngkit'].fillna('Not included')

# %%
pip install mysql-connector-python sqlalchemy pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
data['price']=data['price'].str.strip('Lakhs')

# %%
data['price']=data['price'].replace('95,000','0.95')

# %%
data['price']=data['price'].astype(float)

# %%
data['price']=data['price'].apply(lambda x:x*100000)

# %%
data
# Out:
#           id        company                 model           variant fueltype  \
# 0     555675  MARUTI SUZUKI    CELERIO(2017-2019)     1.0 ZXI AMT O   PETROL
# 1     556383  MARUTI SUZUKI                  ALTO               LXI   PETROL
# 2     556422        HYUNDAI             GRAND I10    1.2 KAPPA ASTA   PETROL
# 3     556771           TATA                 NEXON           XT PLUS   PETROL
# 4     559619           FORD                  FIGO  EXI DURATORQ 1.4   DIESEL
# ...      ...            ...                   ...               ...      ...
# 1059  588906        HYUNDAI  ELITE I20(2020-2020)  ASTA O 1.2 BS VI   PETROL
# 1060  588945        HYUNDAI      XCENT(2017-2020)                 S   PETROL
# 1061  588946       MAHINDRA    SCORPIO(2009-2014)    VLX 2WD BS-III   DIESEL
# 1062  588949  MARUTI SUZUKI         VITARA BREZZA               VDI   DIESEL
# 1063  588950          HONDA                  CITY      SV MT DIESEL   DIESEL
#
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine(
    "mysql+pymysql://root:"YOURPASSSHOULDBEHERE"@localhost/used_cars"
)

engine.connect()

# %%
data.to_sql(
    name='used_cars',
    con=engine,
    if_exists='replace',
    index=False
)
# Out:
# 1064
